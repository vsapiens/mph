# %% [markdown]
# # Clase 4 — Análisis de Rendimiento Deportivo
#
# ## Objetivo
#
# Analizar datos deportivos para encontrar relaciones entre variables y comparar equipos.
#
# Los estudiantes aprenderán a:
# - Crear un gráfico de dispersión para buscar relaciones
# - Usar `groupby` con `mean()` para promedios por grupo
# - Crear un gráfico de barras con datos agrupados
# - Escribir conclusiones y recomendaciones basadas en datos

# %% [markdown]
# ## 1. Importar librerías

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2. Crear el dataset

# %%
datos = {
    "estudiante": ["Ana", "Luis", "Mia", "Omar", "Sara", "Noah"],
    "horas_entreno": [2, 3, 1, 4, 2, 3],
    "puntos": [10, 14, 9, 18, 12, 15],
    "equipo": ["Azul", "Rojo", "Azul", "Verde", "Rojo", "Verde"]
}

df = pd.DataFrame(datos)

# %% [markdown]
# ## 3. Explorar los datos

# %%
df.head()

# %%
df.describe()

# %% [markdown]
# ## 4. Gráfico de dispersión: horas de entreno vs puntos
#
# ¿Hay relación? Si los puntos suben cuando las horas suben, hay una relación positiva.

# %%
plt.scatter(df[2012]["puntos"], df[2013]["puntos"])
plt.title("Horas de entreno vs Puntos")
plt.xlabel("Horas de entreno")
plt.ylabel("Puntos")
plt.show()

# %% [markdown]
# ## 5. Agrupar datos: promedio de puntos por equipo
#
# `groupby` agrupa por equipo y `mean()` calcula el promedio de puntos de cada uno.

# %%
puntos_por_equipo = df.groupby("equipo")["puntos"].mean()
print(puntos_por_equipo)

# %% [markdown]
# ## 6. Gráfico de barras: promedio de puntos por equipo

# %%
puntos_por_equipo.plot(kind="bar")
plt.title("Promedio de puntos por equipo")
plt.xlabel("Equipo")
plt.ylabel("Puntos (promedio)")
plt.show()

# %% [markdown]
# ## Ejercicio
#
# 1. Cambiar horas de entreno o puntos de algunos estudiantes.
# 2. Crear los dos gráficos nuevamente.
# 3. Escribir 1 conclusión (2 frases) sobre lo que observas en los datos.
# 4. Escribir 1 recomendación basada en los resultados.

# %%
datos = {
    "estudiante": ["Ana", "Luis", "Mia", "Omar", "Sara", "Noah"],
    "horas_entreno": [2, 3, 1, 4, 2, 3],
    "puntos": [10, 14, 9, 18, 12, 15],
    "equipo": ["Azul", "Rojo", "Azul", "Verde", "Rojo", "Verde"]
}

excel  = {
    "puntos_por_partido": {
        "puntos": [1,2,3],
        "equipo": ["Atlas","Atlas""Atlas"],
        "numJuego": [0,1,2],
    },
}

[1, 2, 3, 4]
nombres = {
    "Juan", "Pedro", "Emilio", "Ana", "Luis"
}

if datos.get("estudiante", False):
    print("si hay")
else:
    print("no hay")

if datos.get("estudiante", False):
    print("si hay", len(datos["estudiante"]))
else:
    print("no hay")

if "Mia" in datos["estudiante"]:
    print("Si existe Mia")
    print(datos["estudiante"].index("Mia"))

if "Mia" in nombres:
    print("Si existe Mia")
    print(datos["estudiante"].index("Mia"))


datos = {} # diccionario -> buscar y acceder datos rapidos
# = [] # arreglo -> arreglar, ordenar, 

if datos.get("estudiante", False):
    print("si hay")
else:
    print("no hay")
# Out:
# si hay
# si hay 6
# Si existe Mia
# 2
# no hay

# %%
excel  = {
    "puntos_por_partido": {
        "puntos": [1,2,3],
        "equipo": ["Atlas","Atlas""Atlas"],
        "numJuego": [0,1,2],
    },
}

# %%
workbookExcel = {
    "america.xls",
    "atlas.xls"
}

# %%
workbookExcel = {
    "america_2012.xls",
    "atlas.xls"
}

# %%
nombreEquipo = input("Dame tu equipo") #America
anios = int(input("Dame inicio de fecha de busqueda")) #2012 
aniosFinal = int(input("Dame inicio de fecha de busqueda")) #2020

df = {}
# df {2012: df..., 2013: df...}
for index in range(anios, aniosFinal):
    s = ""
    s += nombreEquipo
    s += index
    s += ".csv"

    # s = "America2012.csv"
    df[index] = pd.read_csv('s')

# %%
datos["estudiante"][0] = "Emilio"

# %%
print(datos)
# Out:
# {'estudiante': ['Emilio', 'Luis', 'Mia', 'Omar', 'Sara', 'Noah'], 'horas_entreno': [2, 3, 1, 4, 2, 3], 'puntos': [10, 14, 9, 18, 12, 15], 'equipo': ['Azul', 'Rojo', 'Azul', 'Verde', 'Rojo', 'Verde']}
